# %%
from game.public_goods_game import PublicGoodsGame
import pandas as pd

# %%
strategies = {"coop": 4, "defect": 4, "random": 0}
pgg = PublicGoodsGame(endowment=10,
                      factor=2,
                      strategy=strategies,
                      width=4,
                      height=4,
                      num_neighborhoods=7,
                      local_game=True)

# %%
for i in range(5):
    pgg.run_round()

# %%
pgg.world.to_string()
pgg.game_stats()
# Out:
# ============================
# #     3d6d4 05e29 #
# #     9f240 0104f #
# #     84751 #     5d65c
# 572c1 #     #     8c78a
# ============================
#
#
# Neighborhood: 1
# Agents: [('572c1', 'AlwaysCooperate')]
# Local pot: 320
#
# Neighborhood: 2
# Agents: [('05e29', 'AlwaysDefect'), ('0104f', 'AlwaysDefect')]
# Local pot: 0
#
# Neighborhood: 3
# Agents: [('9f240', 'AlwaysCooperate'), ('84751', 'AlwaysDefect')]
# Local pot: 20
#
# Neighborhood: 4
# Agents: [('3d6d4', 'AlwaysCooperate')]
# Local pot: 320
#
# Neighborhood: 5
# Agents: []
# Local pot: 0
#
# Neighborhood: 6
# Agents: [('8c78a', 'AlwaysCooperate')]
# Local pot: 320
#
# Neighborhood: 7
# Agents: [('5d65c', 'AlwaysDefect')]
# Local pot: 0
#
# Game stats after 5 turns:
# 	Local mode: True
# 	Average contribution: 24.5
# 	Average cooperation: 0.5
# 	Average payoff: 49.0
# 	Public goods: 980
# (49.0, 24.5, 0.5, 5)

# %%
df = pd.DataFrame(pgg.history)
df
# Out:
#    round_number  factor  average_contribution  average_cooperation  \
# 0             1       2                  5.00                  0.5
# 1             2       2                  8.75                  0.5
# 2             3       2                 16.25                  0.5
# 3             4       2                 31.25                  0.5
# 4             5       2                 61.25                  0.5
#
#    average_payoff  public_goods  \
# 0            10.0            80
# 1            17.5           140
# 2            32.5           260
# 3            62.5           500
# 4           122.5           980
#
#                                               agents
# 0  [{'id': '572c1', 'payoff': 20, 'contribution':...
# 1  [{'id': '572c1', 'payoff': 40, 'contribution':...
# 2  [{'id': '572c1', 'payoff': 80, 'contribution':...
# 3  [{'id': '572c1', 'payoff': 160, 'contribution'...
# 4  [{'id': '572c1', 'payoff': 320, 'contribution'...
